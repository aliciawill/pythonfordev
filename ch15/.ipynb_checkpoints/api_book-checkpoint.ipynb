# %%
import requests
import json

'''
GET /v3/search/book HTTP/1.1
Host: dapi.kakao.com
Authorization: KakaoAK {app_key}
'''

url = "https://dapi.kakao.com/v3/search/book"
querystring = {"query":"윤웅식"}
header = {'authorization': 'KakaoAK a0b18d3687c31521d75ed17d422952f6'}
r = requests.get(url, headers=header, params=querystring)

json.loads(r.text)
# Out:
# {'documents': [{'authors': ['윤웅식'],
#    'contents': '『Git GitHub 입문』은 Git과 GitHub를 이용한 버전 관리 시스템을 다루는 방법을 배우는 입문서다. 버전 관리 시스템과 Git 고유의 명령어 중심으로 Git의 기본 개념 및 Git 기반의 대표적인 원격 저장소인 GitHub에 가입해보고 사용하는 방법을 살펴본다. 또한 개발 환경에서 많이 활용되는 대표적인 IDE 4가지인 이클립스, Visual Studio, IntelliJ IDEA, Xcode에서의 Git 사용법과 Git의 고급 명령어',
#    'datetime': '2015-08-20T00:00:00.000+09:00',
#    'isbn': '8968482020 9788968482021',
#    'price': 28000,
#    'publisher': '한빛미디어',
#    'sale_price': 25200,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F945802%3Ftimestamp%3D20190126042612',
#    'title': '만들면서 배우는 Git + GitHub 입문',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=945802&q=%EB%A7%8C%EB%93%A4%EB%A9%B4%EC%84%9C+%EB%B0%B0%EC%9A%B0%EB%8A%94+Git+%2B+GitHub+%EC%9E%85%EB%AC%B8'},
#   {'authors': ['윤웅식'],
#    'contents': '이 책은 다른 프로그래밍 언어를 배운 적 있는 개발자가 파이썬 3를 빠르게 배울 수 있게 도와준다. 꼭 필요한 핵심 문법만 간략히 설명한 후, 파일 입출력, 웹 크롤러, 슬랙 봇 만들기, 메시지 큐 사용하기, 팬더스(pandas)를 이용한 데이터 분석 등 실제 현업에서 사용해볼 만한 예제를 엄선해 소개한다. 실무에서 주로 사용하는 pip, venv, Jupyter Notebook 사용법도 알려준다.',
#    'datetime': '2017-11-01T00:00:00.000+09:00',
#    'isbn': '1162240202 9791162240205',
#    'price': 20000,
#    'publisher': '한빛미디어',
#    'sale_price': 18000,
#    'status': '정상판매',
#    'thumbnail': 'https://search1.kakaocdn.net/thumb/R120x174.q85/?fname=http%3A%2F%2Ft1.daumcdn.net%2Flbook%2Fimage%2F1608691%3Ftimestamp%3D20190131061201',
#    'title': '개발자를 위한 파이썬',
#    'translators': [],
#    'url': 'https://search.daum.net/search?w=bookpage&bookId=1608691&q=%EA%B0%9C%EB%B0%9C%EC%9E%90%EB%A5%BC+%EC%9C%84%ED%95%9C+%ED%8C%8C%EC%9D%B4%EC%8D%AC'}],
#  'meta': {'is_end': True, 'pageable_count': 2, 'total_count': 2}}

# %%
import requests
import json

url = "https://openapi.naver.com/v1/search/book.json?"
client_id = "q62rKwxf5gxV0v9keWOU"
client_secret = "_RoC88vfAr"

q = "query=" + "윤웅식"

headers = {
    "X-Naver-Client-Id":client_id,
    "X-Naver-Client-secret":client_secret
}

r = requests.get(url+q, headers=headers)
json.loads(r.text)
# Out:
# {'lastBuildDate': 'Mon, 04 Feb 2019 19:35:47 +0900',
#  'total': 2,
#  'start': 1,
#  'display': 2,
#  'items': [{'title': '만들면서 배우는 Git GitHub 입문 (세상의 모든 개발 코드를 공유하고 관리하는 소셜 코딩)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=9415223',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/094/152/09415223.jpg?type=m1&udate=20190204',
#    'author': '<b>윤웅식</b>',
#    'price': '28000',
#    'discount': '25200',
#    'publisher': '한빛미디어',
#    'pubdate': '20150820',
#    'isbn': '8968482020 9788968482021',
#    'description': '『GIT GITHUB 입문』은 GIT과 GITHUB를 이용한 버전 관리 시스템을 다루는 방법을 배우는 입문서다. 버전 관리 시스템과 GIT 고유의 명령어 중심으로 GIT의 기본 개념 및 GIT 기반의 대표적인 원격 저장소인 GITHUB에 가입해보고 사용하는 방법을 살펴본다. 또한 개발 환경에서 많이... '},
#   {'title': '개발자를 위한 파이썬 (현장에서 일하는 개발자 맞춤 입문서)',
#    'link': 'http://book.naver.com/bookdb/book_detail.php?bid=12706439',
#    'image': 'https://bookthumb-phinf.pstatic.net/cover/127/064/12706439.jpg?type=m1&udate=20180426',
#    'author': '<b>윤웅식</b>',
#    'price': '20000',
#    'discount': '18000',
#    'publisher': '한빛미디어',
#    'pubdate': '20171101',
#    'isbn': '1162240202 9791162240205',
#    'description': '프로그래밍 언어를 배웠다면 이 책으로 파이썬을 공부하자\n\n이 책은 다른 프로그래밍 언어를 배운 적 있는 개발자가 파이썬 3를 빠르게 배울 수 있게 도와준다. 꼭 필요한 핵심 문법만 간략히 설명한 후, 파일 입출력, 웹 크롤러, 슬랙 봇 만들기, 메시지 큐 사용하기, 팬더스(pandas)를 이용한 데이터... '}]}

# %%
#https://api.themoviedb.org/3/movie/550?api_key=6a83528b368de764278024ed74e27c4a
import requests
import json

url = "https://api.themoviedb.org/3/search/movie"
p = {
    'api_key': '6a83528b368de764278024ed74e27c4a',
    'query': "iron man"
}

r = requests.get(url, params=p)
json.loads(r.text)
# Out:
# {'page': 1,
#  'total_results': 50,
#  'total_pages': 3,
#  'results': [{'vote_count': 14129,
#    'id': 1726,
#    'video': False,
#    'vote_average': 7.5,
#    'title': 'Iron Man',
#    'popularity': 31.878,
#    'poster_path': '/848chlIWVT41VtAAgyh9bWymAYb.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man',
#    'genre_ids': [28, 878, 12],
#    'backdrop_path': '/ZQixhAZx6fH1VNafFXsqa1B8QI.jpg',
#    'adult': False,
#    'overview': 'After being held captive in an Afghan cave, billionaire engineer Tony Stark creates a unique weaponized suit of armor to fight evil.',
#    'release_date': '2008-04-30'},
#   {'vote_count': 12987,
#    'id': 68721,
#    'video': False,
#    'vote_average': 6.9,
#    'title': 'Iron Man 3',
#    'popularity': 30.267,
#    'poster_path': '/1Ilv6ryHUv6rt9zIsbSEJUmmbEi.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man 3',
#    'genre_ids': [28, 12, 878],
#    'backdrop_path': '/n9X2DKItL3V0yq1q1jrk8z5UAki.jpg',
#    'adult': False,
#    'overview': "When Tony Stark's world is torn apart by a formidable terrorist called the Mandarin, he starts an odyssey of rebuilding and retribution.",
#    'release_date': '2013-04-18'},
#   {'vote_count': 11068,
#    'id': 10138,
#    'video': False,
#    'vote_average': 6.7,
#    'title': 'Iron Man 2',
#    'popularity': 25.092,
#    'poster_path': '/ArqpkNYGfcTIA6umWt6xihfIZZv.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man 2',
#    'genre_ids': [12, 28, 878],
#    'backdrop_path': '/jxdSxqAFrdioKgXwgTs5Qfbazjq.jpg',
#    'adult': False,
#    'overview': "With the world now aware of his dual life as the armored superhero Iron Man, billionaire inventor Tony Stark faces pressure from the government, the press and the public to share his technology with the military. Unwilling to let go of his invention, Stark, with Pepper Potts and James 'Rhodey' Rhodes at his side, must forge new alliances – and confront powerful enemies.",
#    'release_date': '2010-04-28'},
#   {'vote_count': 1883,
#    'id': 9313,
#    'video': False,
#    'vote_average': 6.5,
#    'title': 'The Man in the Iron Mask',
#    'popularity': 13.673,
#    'poster_path': '/mNbLk9qdBMnzBFWBrjy3Nuw9Ovi.jpg',
#    'original_language': 'en',
#    'original_title': 'The Man in the Iron Mask',
#    'genre_ids': [28, 12, 18, 36],
#    'backdrop_path': '/c8znzyczeHuSe2xP0HyQ0sLUsDD.jpg',
#    'adult': False,
#    'overview': "Years have passed since the Three Musketeers, Aramis, Athos and Porthos, have fought together with their friend, D'Artagnan. But with the tyrannical King Louis using his power to wreak havoc in the kingdom while his twin brother, Philippe, remains imprisoned, the Musketeers reunite to abduct Louis and replace him with Philippe.",
#    'release_date': '1998-03-12'},
#   {'vote_count': 247,
#    'id': 339259,
#    'video': False,
#    'vote_average': 6.5,
#    'title': 'The Man with the Iron Heart',
#    'popularity': 13.076,
#    'poster_path': '/ZVQfCY2DgCjrm8w2saXvT8Ao3B.jpg',
#    'original_language': 'en',
#    'original_title': 'The Man with the Iron Heart',
#    'genre_ids': [10752, 28, 36, 53],
#    'backdrop_path': '/ypyz71O2YtI5rdJ7Y3s03SwwORQ.jpg',
#    'adult': False,
#    'overview': 'With the Third Reich is at his peak in 1942, the Czech resistance in London plans the most ambitious military operation of WWII –  Anthropoid. Two young recruits are sent to Prague to assassinate the most ruthless Nazi leader – Reinhardt Heydrich – head of the SS, the Gestapo and the architect of the Final Solution.',
#    'release_date': '2017-05-25'},
#   {'vote_count': 63,
#    'id': 13647,
#    'video': False,
#    'vote_average': 5.7,
#    'title': 'The Invincible Iron Man',
#    'popularity': 4.326,
#    'poster_path': '/7jDmWZW0C9nXEgsKNGs1nZT1EPv.jpg',
#    'original_language': 'en',
#    'original_title': 'The Invincible Iron Man',
#    'genre_ids': [28, 12, 16, 14, 878],
#    'backdrop_path': '/oUi2pvNbHCUiEFSqawp5dJdQNMK.jpg',
#    'adult': False,
#    'overview': "When a cocky industrialist's efforts to raise an ancient Chinese temple leads him to be seriously wounded and captured by enemy forces, he must use his ideas for a revolutionary power armor in order to fight back as a superhero.",
#    'release_date': '2007-01-23'},
#   {'vote_count': 540,
#    'id': 97430,
#    'video': False,
#    'vote_average': 5.3,
#    'title': 'The Man with the Iron Fists',
#    'popularity': 8.156,
#    'poster_path': '/rYnPhYmG4qyWSXRmVUlzmlA0RFg.jpg',
#    'original_language': 'en',
#    'original_title': 'The Man with the Iron Fists',
#    'genre_ids': [28],
#    'backdrop_path': '/uSZweG7S50fe8vqMHnJHl8H6S33.jpg',
#    'adult': False,
#    'overview': 'In feudal China, a blacksmith who makes weapons for a small village is put in the position where he must defend himself and his fellow villagers.',
#    'release_date': '2012-11-02'},
#   {'vote_count': 87,
#    'id': 321494,
#    'video': False,
#    'vote_average': 4.9,
#    'title': 'The Man with the Iron Fists 2',
#    'popularity': 5.824,
#    'poster_path': '/njPa0RO0KKmwBCGHcEOTbxljftF.jpg',
#    'original_language': 'en',
#    'original_title': 'The Man with the Iron Fists 2',
#    'genre_ids': [28],
#    'backdrop_path': '/umJaQKA3T7IGRlrRdUvlOuS31xo.jpg',
#    'adult': False,
#    'overview': 'When a stranger, Thaddeus, is found badly wounded near the village, miner Li Kung and his wife Ah Ni offer him refuge. As he heals, he becomes entrenched in a conflict that pits the townsfolk against the evil Master Ho, his nefarious Beetle Clan and the terrifying Lord Pi.',
#    'release_date': '2015-03-10'},
#   {'vote_count': 80,
#    'id': 169934,
#    'video': False,
#    'vote_average': 5.4,
#    'title': 'Iron Man: Rise of Technovore',
#    'popularity': 5.526,
#    'poster_path': '/jHo43hitRyIMPC5y3tCxmZow0uN.jpg',
#    'original_language': 'ja',
#    'original_title': 'アイアンマン：ライズ・オブ・テクノヴォア',
#    'genre_ids': [878, 16, 28],
#    'backdrop_path': '/1kXtLaTyuUT0zNZyglhNJBTC5mM.jpg',
#    'adult': False,
#    'overview': "Iron Man enlists the help of ruthless vigilante the Punisher to track down War Machine's murderer. All the while, he's being pursued by S.H.I.E.L.D. agents Black Widow and Hawkeye, who suspect his involvement in a recent terrorist plot.",
#    'release_date': '2013-04-24'},
#   {'vote_count': 68,
#    'id': 230896,
#    'video': False,
#    'vote_average': 5.2,
#    'title': 'Iron Man & Hulk: Heroes United',
#    'popularity': 5.647,
#    'poster_path': '/4vPNRJtPjtg7WB6G37ZoQ8dFIjE.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man & Hulk: Heroes United',
#    'genre_ids': [28, 12, 16, 10751],
#    'backdrop_path': '/eDa6tmysT8wL25RrwrGrpNVwZxu.jpg',
#    'adult': False,
#    'overview': "The Invincible Iron Man and the Incredible Hulk must join forces to save the Earth from its greatest threat yet! When two Hydra scientists try to supercharge a Stark Arc Reactor with Hulk's Gamma Energy, they unleash a being of pure electricity called Zzzax - and he's hungry for destruction. Together, Iron Man and Hulk are the only force that stands in the way of the Zzzax's planetary blackout. But first, the super heroic duo will have to get through snarling Wendigos, deadly robots and the scaly powerhouse, Abomination.  Can two of Marvel's mightiest heroes find a way to work together without smashing each other before time runs out?",
#    'release_date': '2013-12-03'},
#   {'vote_count': 3,
#    'id': 194310,
#    'video': False,
#    'vote_average': 6.7,
#    'title': 'Iron Man',
#    'popularity': 1.4,
#    'poster_path': '/zyvl5y4iphmmAAQdZ37maFyvaE0.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man',
#    'genre_ids': [18],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Prizefighter Mason loses his opening fight so wife Rose leaves him for Hollywood. Without her around Mason trains and starts winning. Rose comes back and wants Mason to dump his manager Regan and replace him with her secret lover Lewis.',
#    'release_date': '1931-04-29'},
#   {'vote_count': 18,
#    'id': 278256,
#    'video': False,
#    'vote_average': 7.2,
#    'title': 'Bartali: The Iron Man',
#    'popularity': 1.344,
#    'poster_path': '/nX8HhJxZeFsAJD6SpbqIae6K9Ub.jpg',
#    'original_language': 'it',
#    'original_title': "Gino Bartali - L'intramontabile",
#    'genre_ids': [10770],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'TV Miniseries (2 episodes) about life and rivalry of italian bikers Gino Bartali and Fausto Coppi.',
#    'release_date': '2006-03-26'},
#   {'vote_count': 31,
#    'id': 284274,
#    'video': False,
#    'vote_average': 5.6,
#    'title': 'Iron Man and Captain America: Heroes United',
#    'popularity': 3.174,
#    'poster_path': '/5li3ZIIPrjb6bmSFy7wp6J0Z8no.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man and Captain America: Heroes United',
#    'genre_ids': [12, 16, 28],
#    'backdrop_path': '/wvg8adyEqpmiCVxoRmR6ZOIbww.jpg',
#    'adult': False,
#    'overview': 'Iron Man and Captain America battle to keep the Red Skull and his triggerman, Taskmaster, from unleashing an army of Hydra Brutes on the world!  Sequel to the film "Iron Man & Hulk: Heroes United" and feature Iron Man teaming up with Captain America, it comes to accompany the live-action film "Captain America: The Winter Soldier".',
#    'release_date': '2014-07-29'},
#   {'vote_count': 19,
#    'id': 4199,
#    'video': False,
#    'vote_average': 6.5,
#    'title': 'The Man in the Iron Mask',
#    'popularity': 2.493,
#    'poster_path': '/30JmeTsNT1CCsGGEyveTdDW1tCT.jpg',
#    'original_language': 'en',
#    'original_title': 'The Man in the Iron Mask',
#    'genre_ids': [36, 12],
#    'backdrop_path': '/7rgabNcJB2jPmWU1TqMzWMBrtbR.jpg',
#    'adult': False,
#    'overview': "The story of Louis XIV of France and his attempts to keep his identical twin brother Philippe imprisoned away from sight and knowledge of the public, and Philippe's rescue by the aging Musketeers, led by D'Artagnan.",
#    'release_date': '1977-07-07'},
#   {'vote_count': 1,
#    'id': 69592,
#    'video': False,
#    'vote_average': 5,
#    'title': 'Iron Man',
#    'popularity': 0.889,
#    'poster_path': '/hcpm8d6cqo3rVqpfVPUk2IRHGRD.jpg',
#    'original_language': 'en',
#    'original_title': 'Iron Man',
#    'genre_ids': [18],
#    'backdrop_path': '/u36if7fq60FXOnCgBEQpafyEJwT.jpg',
#    'adult': False,
#    'overview': 'In Coaltown, Pennsylvania, miner Coke Mason hopes to better himself, buy a radio store, and marry Rose Warren. His gambler brother George thinks Coke can be more successful as a boxer, knowing that when he fights he\'s consumed with a murderous rage that makes him an "iron man." Seeing dollar signs in Rose\'s eyes, Coke reluctantly agrees, though he\'s fearful of the "killer instinct" that makes him a knockout success in the ring...and brings him the booing hatred of the fans. Will Coke throw off his personal demon before he kills someone?',
#    'release_date': '1951-08-18'},
#   {'vote_count': 7,
#    'id': 43836,
#    'video': False,
#    'vote_average': 6.9,
#    'title': 'The Man in the Iron Mask',
#    'popularity': 2.229,
#    'poster_path': '/tVPCpQaEIze26y3XiCn2dGHYbR1.jpg',
#    'original_language': 'en',
#    'original_title': 'The Man in the Iron Mask',
#    'genre_ids': [10749, 18],
#    'backdrop_path': '/sen7Iu5widsUtMZ30UhQBTy2E1C.jpg',
#    'adult': False,
#    'overview': "The Three Musketeers rescue the king's unjustly imprisoned twin.",
#    'release_date': '1939-07-13'},
#   {'vote_count': 0,
#    'id': 575143,
#    'video': True,
#    'vote_average': 0,
#    'title': 'I Am Iron Man',
#    'popularity': 1.274,
#    'poster_path': '/81g0nJdNEMiZCBqAbsN17LeSSZp.jpg',
#    'original_language': 'en',
#    'original_title': 'I Am Iron Man',
#    'genre_ids': [878, 18, 28],
#    'backdrop_path': '/l0KcJgbLwQzWnO0oLo3F8H96IqU.jpg',
#    'adult': False,
#    'overview': 'This is a tribute to the one who started it all - Tony Stark',
#    'release_date': '2018-07-31'},
#   {'vote_count': 1,
#    'id': 101803,
#    'video': False,
#    'vote_average': 8,
#    'title': 'Sam Peckinpah: Man of Iron',
#    'popularity': 1.4,
#    'poster_path': '/peLpmC0FNcSZWq5FcWkdgm8RStG.jpg',
#    'original_language': 'en',
#    'original_title': 'Sam Peckinpah: Man of Iron',
#    'genre_ids': [99],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': "This straight-talking program seeks to understand the enigmatic and controversial Sam Peckinpah, whose violent films such as The Wild Bunch and Straw Dogs had a telling effect on the cinema of the 1970s and 80s. Those who knew and worked with him, including actor James Coburn, actress Ali MacGraw, his associate Katherine Haber, his cousin Bob Peckinpah, and several screenwriters and producers, examine his life in an attempt to separate the man from the persona. Clips from key films reinforce this detailed discussion of Peckinpah's art and a fixation on violence that still permeates Hollywood today.",
#    'release_date': '1993-06-29'},
#   {'vote_count': 0,
#    'id': 488439,
#    'video': False,
#    'vote_average': 0,
#    'title': 'Iron Man',
#    'popularity': 0.6,
#    'poster_path': '/5DYCZoBzKzrJyNXPHq0ZpLWHR3E.jpg',
#    'original_language': 'zh',
#    'original_title': '中國鈇人',
#    'genre_ids': [28, 12],
#    'backdrop_path': None,
#    'adult': False,
#    'overview': 'Iron Man is a Taiwan Martial Arts movie',
#    'release_date': '1973-10-09'},
#   {'vote_count': 184,
#    'id': 41428,
#    'video': False,
#    'vote_average': 6.9,
#    'title': 'Tetsuo: The Iron Man',
#    'popularity': 6.275,
#    'poster_path': '/sIygsUfPDD7pfdvmZR9PKArZ2Jp.jpg',
#    'original_language': 'ja',
#    'original_title': '鉄男',
#    'genre_ids': [27, 878],
#    'backdrop_path': '/6dPHC0BOIqneXxh14EnXHKj3tmv.jpg',
#    'adult': False,
#    'overview': 'Tetsuo: The Iron Man is a 1989 Japanese cyberpunk film by cult-film director Shinya Tsukamoto produced by Japan Home Video. This, his third film, is an extremely graphic but also strikingly-filmed fantasy shot in the same low-budget, underground-production style as his first two films. Revolving around the transformation of people into grotesque hybrids of flesh and metal, Tetsuo is above all an overwhelming audiovisual experience, set to a brain-pounding score by Chu Ishikawa and complemented by suitably exaggerated sound effects.',
#    'release_date': '1989-07-01'}]}
